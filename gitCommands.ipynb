# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)

# %cd /content/drive/MyDrive/Colab\ Notebooks/GitHub/AmazonReview
# !pwd
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Colab Notebooks/GitHub
# /content/drive/MyDrive/Colab Notebooks/GitHub

# %%
# MAJOR CHANGES
# Set current working project repo
repository = 'AmazonReview_UsefulnessRanker'

# %%
# Declare git credentials
username = 'rameshs-data'
useremail = "ramesh.s.data@gmail.com"
git_token = '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'

url_template = "https://{username}:{git_token}@github.com/{username}/{repository}"
url = url_template.format(username=username, git_token=git_token, repository=repository)
#print(url)

# %%
# !git config --global user.email {useremail}
# !git config --global user.name {username}
# !git config --global credential.username {username}
# !git config --global credential.helper store
# !git config --global credential.helper cache

# %%
#!git clone -b dev https://{git_token}@github.com/{username}/{repository}
# %cd {repository}
# %ls -a
# Out:
# [Errno 2] No such file or directory: 'AmazonReview_UsefulnessRanker'
# /content/drive/MyDrive/Colab Notebooks/GitHub/AmazonReview_UsefulnessRanker
# .git/  gitCommands.ipynb  README.md

# %%
# !git init
# !touch .gitignore
# !git add .gitignore
# Out:
# Reinitialized existing Git repository in /content/TextClassifier-NLP/.git/

# %%
# !git status
# Out:
# On branch dev
# Your branch is up to date with 'origin/dev'.
#
# nothing to commit, working tree clean

# %%
#!git rm README.md
# !git add .

# %%
# !git status
# Out:
# On branch main
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   NLP/10_word_embedding_techniques.ipynb
# 	new file:   NLP/11_fake_news_LSTM/11_LSTM_FakeNewsClassifier.ipynb
# 	new file:   NLP/11_fake_news_LSTM/data/submit.csv
# 	new file:   NLP/11_fake_news_LSTM/data/test.csv
# 	new file:   NLP/11_fake_news_LSTM/data/train.csv
# 	modified:   NLP/7_Word2Vec_example.ipynb
# 	new file:   NLP/9_RNN_example.ipynb
# 	modified:   Python/1_Arrays.ipynb

# %%
# !git commit -m "Initial Commit"
# Out:
# [main 69f56bd] Word2vec, LSTM & Arrays notebooks
#  8 files changed, 188572 insertions(+), 2 deletions(-)
#  create mode 100644 NLP/10_word_embedding_techniques.ipynb
#  create mode 100644 NLP/11_fake_news_LSTM/11_LSTM_FakeNewsClassifier.ipynb
#  create mode 100644 NLP/11_fake_news_LSTM/data/submit.csv
#  create mode 100644 NLP/11_fake_news_LSTM/data/test.csv
#  create mode 100644 NLP/11_fake_news_LSTM/data/train.csv
#  rewrite NLP/7_Word2Vec_example.ipynb (93%)
#  create mode 100644 NLP/9_RNN_example.ipynb
#  rewrite Python/1_Arrays.ipynb (99%)

# %%
# Out:
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), 2.39 KiB | 40.00 KiB/s, done.
# From https://github.com/rameshs-data/TextClassifier-NLP
#  * branch            main       -> FETCH_HEAD
#    db44d7d..4b07ae0  main       -> origin/main
# Updating d5817f9..4b07ae0
# Fast-forward
#  README.md | 32 ++++++++++++++++++++++++++++++++
#  1 file changed, 32 insertions(+)
#  create mode 100644 README.md

# %%
#!git pull origin dev
# !git push https://{username}:{git_token}@github.com/{username}/{repository} dev
# Out:
# Enumerating objects: 19, done.
# Counting objects: 100% (19/19), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (13/13), done.
# Writing objects: 100% (14/14), 46.00 MiB | 4.34 MiB/s, done.
# Total 14 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 2 local objects.
# remote: warning: See https://gh.io/lfs for more information.
# remote: warning: File NLP/11_fake_news_LSTM/data/train.csv is 94.06 MB; this is larger than GitHub's recommended maximum file size of 50.00 MB
# remote: warning: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# To https://github.com/rameshs-data/Data-Science-Portfolio
#    48209ee..69f56bd  main -> main
